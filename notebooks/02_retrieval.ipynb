# %% [markdown]
# # 02 · Retrieval / RAG index  _(owner: M2)_
#
# Build the ChromaDB glossary index over MedlinePlus + lay-health guidelines; measure retrieval hit quality; wire it into the Simplifier.
