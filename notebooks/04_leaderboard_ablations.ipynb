# %% [markdown]
# # 04 · Leaderboard & ablations  _(owner: M4)_
#
# Run pipeline vs. single-LLM baseline across ≥3 models; drop one agent at a time; report faithfulness, readability, latency, cost, openness.
