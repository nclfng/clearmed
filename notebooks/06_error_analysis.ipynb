# %% [markdown]
# # 06 · Error analysis  _(shared, Phase 2)_
#
# Categorize hallucinations by content type (lab values, drug names, procedures); which agent introduces vs. catches each; representative failure traces.
