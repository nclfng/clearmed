# %% [markdown]
# # 03 · Verifier calibration  _(owner: M3)_
#
# Score the Verifier against MedAESQA human labels; iterate the prompt until Cohen's κ ≥ 0.6 / agreement ≥ 80%; show confusion matrices.
